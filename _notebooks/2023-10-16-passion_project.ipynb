# %% [markdown]
# ---
# toc: true
# comments: true
# layout: post
# title: gameee
# description: Iterations in Python
# type: hacks
# courses: { compsci: {week: 4} }
# ---

# %% [markdown]
# ## Passion Project
# Aditi Bharadwaj, Cindy Liang, Eshika Pallapottu, Samhtia L

# %%
# %%html
# <html>
# <body>
#
# <h1>Did you know that climate change causes lung cancer?</h1>
# <p>Yes, that's right. According to the American Lung Association, rising temperatures, wildfires and poor air quality.</p>
#
# </body>
# </html>
# Out:
# <html>
# <body>
#
# <h1>Did you know that climate change causes lung cancer?</h1>
# <p>Yes, that's right. According to the American Lung Association, rising temperatures, wildfires and poor air quality.</p>
#
# </body>
# </html>

# %%
# %%html
# <html>
# <head>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#         }
#         #game-container {
#             width: 400px;
#             margin: 0 auto;
#         }
#         .character {
#             width: 40px;
#             height: 40px;
#             background-color: green;
#             position: absolute;
#         }
#         .item {
#             width: 20px;
#             height: 20px;
#             background-color: yellow;
#             position: absolute;
#         }
#         .obstacle {
#             width: 30px;
#             height: 30px;
#             background-color: red;
#             position: absolute;
#         }
#     </style>
# </head>
# <body>
#     <h1>Climate Change Adventure</h1>
#     <div id="game-container">
#         <div class="character" id="player"></div>
#     </div>
#
#     <script>
#         const player = document.getElementById("player");
#         let playerX = 0;
#         let score = 0;
#
#         function movePlayer(event) {
#             if (event.key === "ArrowRight" && playerX < 360) {
#                 playerX += 20;
#             } else if (event.key === "ArrowLeft" && playerX > 0) {
#                 playerX -= 20;
#             }
#
#             player.style.left = playerX + "px";
#
#             collectItem();
#             avoidObstacle();
#         }
#
#         function collectItem() {
#             const items = document.querySelectorAll(".item");
#             items.forEach((item) => {
#                 if (isColliding(player, item)) {
#                     item.style.display = "none";
#                     score++;
#                     console.log("Score: " + score);
#                 }
#             });
#         }
#
#         function avoidObstacle() {
#             const obstacles = document.querySelectorAll(".obstacle");
#             obstacles.forEach((obstacle) => {
#                 if (isColliding(player, obstacle)) {
#                     alert("Game Over! Your final score: " + score);
#                     location.reload(); // Restart the game
#                 }
#             });
#         }
#
#         function isColliding(element1, element2) {
#             const rect1 = element1.getBoundingClientRect();
#             const rect2 = element2.getBoundingClientRect();
#             return (
#                 rect1.left < rect2.right &&
#                 rect1.right > rect2.left &&
#                 rect1.top < rect2.bottom &&
#                 rect1.bottom > rect2.top
#             );
#         }
#
#         document.addEventListener("keydown", movePlayer);
#     </script>
# </body>
# </html>
# Out:
# <html>
# <head>
#     <style>
#         body {
#             font-family: Arial, sans-serif;
#         }
#         #game-container {
#             width: 400px;
#             margin: 0 auto;
#         }
#         .character {
#             width: 40px;
#             height: 40px;
#             background-color: green;
#             position: absolute;
#         }
#         .item {
#             width: 20px;
#             height: 20px;
#             background-color: yellow;
#             position: absolute;
#         }
#         .obstacle {
#             width: 30px;
#             height: 30px;
#             background-color: red;
#             position: absolute;
#         }
#     </style>
# </head>
# <body>
#     <h1>Climate Change Adventure</h1>
#     <div id="game-container">
#         <div class="character" id="player"></div>
#     </div>
#
#     <script>
#         const player = document.getElementById("player");
#         let playerX = 0;
#         let score = 0;
#
# ...
